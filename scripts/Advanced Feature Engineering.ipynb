# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import re
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from sklearn.feature_extraction.text import TfidfVectorizer
import json
import warnings
warnings.filterwarnings("ignore")

# %%
file_path = "../data/electrify__applied_ai_engineer__training_data.csv"
df = pd.read_csv(file_path) #

# %%
def tokenize_no_stop(text):
    tokens = re.findall(r"\b\w+\b", str(text).lower())
    return [w for w in tokens if (w not in ENGLISH_STOP_WORDS) & (len(w) >= 2) & (not(w.isdigit()))]

# %%
df['tokens'] = df['title'].apply(tokenize_no_stop)
rez = {}
for channel_id, group in df.groupby('channel_id'):
    threshold = group['views_in_period'].quantile(0.75)
    high_group = group[group['views_in_period'] >= threshold]
    low_group = group[group['views_in_period'] < threshold]
    high_counts = Counter()
    for tokens in high_group['tokens']:
        high_counts.update(set(tokens))
    low_counts = Counter()
    for tokens in low_group['tokens']:
        low_counts.update(set(tokens))
    n_high = len(high_group)
    n_low = len(low_group)
    keyword_scores = {}
    for token in set(high_counts.keys()).union(low_counts.keys()):
        high_freq = high_counts[token] / n_high if n_high else 0
        low_freq = low_counts[token] / n_low if n_low else 0
        score = (high_freq + 1e-5) / (low_freq + 1e-5)
        keyword_scores[token] = score
    sorted_tokens = sorted(keyword_scores.items(), key=lambda x: x[1], reverse=True)
    top_keywords = [t for t,_ in sorted_tokens[:20]]
    low_keywords = [t for t,_ in sorted_tokens[-20:]]
    rez[channel_id] = {'top_keywords': top_keywords, 'low_keywords': low_keywords}

# %%
rez
# Out:
# {'UC-9b7aDP6ZN0coj9-xFnrtw': {'top_keywords': ['voyager',
#    'problems',
#    'pluto',
#    'wrong',
#    'outside',
#    'asteroid',
#    'backwards',
#    'exoplanet',
#    'detected',
#    'affect',
#    'coming',
#    'seen',
#    'experiment',
#    'best',
#    'deepest',
#    'nearly',
#    'closest',
#    'sdo',
#    'proxima',
#    'jupiter'],
#   'low_keywords': ['model',
#    'scientists',
#    'designed',
#    'looks',
#    'supercut',
#    'shouldn',
#    've',
#    'black',
#    'satellites',
#    'mercury',
#    'big',
#    'theory',
#    'space',
#    'weird',
#    'crash',
#    'physics',
#    'nasa',
#    'years',
#    'images',
#    'moon']},
#  'UC510QYlOlKNyhy_zdQxnGYw': {'top_keywords': ['communist',
#    'best',
#    'screwups',
#    'sturmtiger',
#    'haiti',
#    'panther',
#    'hussein',
#    'assassinations',
#    'lai',
#    'stop',
#    'oversized',
#    'horrors',
#    'flattest',
#    'warriors',
#    'lifestyle',
#    'disappointments',
#    'cursed',
#    'hell',
#    'castle',
#    'evil'],
#   'low_keywords': ['crazy',
#    'russia',
#    'shoot',
#    'vietnam',
#    'fighting',
#    'don',
#    'does',
#    'weird',
#    'axis',
#    'terrifying',
#    'things',
#    'north',
#    'story',
#    'tanks',
#    'ww1',
#    'vs',
#    'gun',
#    'wwii',
#    'soldier',
#    'korean']},
#  'UC_WXkNIJ2ncLIsAk_ltbvjA': {'top_keywords': ['lazy',
#    'apart',
#    'wants',
#    'gets',
#    'remember',
#    'extreme',
#    'fakes',
#    'destroyed',
#    'minifigures',
#    'play',
#    'features',
#    'break',
#    'rules',
#    'sets',
#    'worst',
#    'bricks',
#    'iq',
#    'lego',
#    'talks',
#    'hottest'],
#   'low_keywords': ['brittle',
#    'theories',
#    'cars',
#    'far',
#    'lots',
#    'instruction',
#    'misleading',
#    'changed',
#    'epic',
#    'steps',
#    'crazy',
#    'obsession',
#    'vs',
#    'techniques',
#    'set',
#    'obsessions',
#    'building',
#    'takes',
#    'weird',
#    'hot']}}

# %%
tfidf_rez = {}
for channel_id, group in df.groupby("channel_id"):
    threshold = group["views_in_period"].quantile(0.75)
    high_group = group[group["views_in_period"] >= threshold]
    low_group  = group[group["views_in_period"] <  threshold]

    vectoriser = TfidfVectorizer(
        stop_words="english",
        token_pattern=r"\b[a-zA-Z]{2,}\b",
    )
    titles_all = pd.concat([high_group["title"], low_group["title"]])
    vectoriser.fit(titles_all)

    tfidf_high = vectoriser.transform(high_group["title"])
    tfidf_low  = vectoriser.transform(low_group["title"])
    vocab = vectoriser.get_feature_names_out()

    high_avg = tfidf_high.sum(axis=0).A1 / max(len(high_group), 1)
    low_avg  = tfidf_low.sum(axis=0).A1  / max(len(low_group), 1)

    tfidf_scores = {
        token: (high_avg[idx] + 1e-6) / (low_avg[idx] + 1e-6)
        for idx, token in enumerate(vocab)
    }

    sorted_tfidf = sorted(tfidf_scores.items(), key=lambda x: x[1], reverse=True)
    tfidf_top = [t for t, _ in sorted_tfidf[:10]]
    tfidf_low = [t for t, _ in sorted_tfidf[-10:]]

    tfidf_rez[channel_id] = {
        "tfidf_top_keywords": tfidf_top,
        "tfidf_low_keywords": tfidf_low,
    }

# %%
tfidf_rez
# Out:
# {'UC-9b7aDP6ZN0coj9-xFnrtw': {'tfidf_top_keywords': ['voyager',
#    'aliens',
#    'discover',
#    'detected',
#    'edge',
#    'deepest',
#    'sdo',
#    'seen',
#    'jupiter',
#    'neptune'],
#   'tfidf_low_keywords': ['black',
#    'big',
#    'years',
#    'weird',
#    'mercury',
#    'images',
#    'space',
#    'nasa',
#    'satellites',
#    'moon']},
#  'UC510QYlOlKNyhy_zdQxnGYw': {'tfidf_top_keywords': ['oversized',
#    'best',
#    'disappointments',
#    'betrayals',
#    'unfair',
#    'today',
#    'assassinations',
#    'fearsome',
#    'notable',
#    'warriors'],
#   'tfidf_low_keywords': ['vs',
#    'story',
#    'terrifying',
#    'axis',
#    'wwii',
#    'north',
#    'korean',
#    'tanks',
#    'things',
#    'soldier']},
#  'UC_WXkNIJ2ncLIsAk_ltbvjA': {'tfidf_top_keywords': ['apart',
#    'remember',
#    'extreme',
#    'fakes',
#    'gets',
#    'lazy',
#    'destroyed',
#    'wants',
#    'minifigures',
#    'features'],
#   'tfidf_low_keywords': ['obsession',
#    'talks',
#    'set',
#    'vs',
#    'building',
#    'techniques',
#    'obsessions',
#    'weird',
#    'hot',
#    'takes']}}

# %%
clean_titles_temp = df['title'].astype(str).str.strip()

# %%
clean_titles_temp
# Out:
# 0      Why Does Russia insist on still using Armored ...
# 1                Absurd Stories from the Afghanistan War
# 2       Bro does Beer Run for his Buddies in Vietnam War
# 3      How a Lone US Sub Destroyed Japan's Most Impor...
# 4                Waffen SS vs. Vietcong - Who Would Win?
#                              ...
# 206    The Star Explosion So Powerful, It Compressed ...
# 207    What Voyager Detected at the Edge of the Solar...
# 208    What They Didn't Teach You in School about Nep...
# 209    How Are Ghost Particles Affecting Earth? | Ice...
# 210    NASA Tried to Screw Astronauts Over Money - an...
# Name: title, Length: 211, dtype: object

# %%
clean_titles_temp = clean_titles_temp.str.split().str[0]
clean_titles_temp
# Out:
# 0         Why
# 1      Absurd
# 2         Bro
# 3         How
# 4      Waffen
#         ...
# 206       The
# 207      What
# 208      What
# 209       How
# 210      NASA
# Name: title, Length: 211, dtype: object

# %%
clean_titles_temp = clean_titles_temp.dropna().str.lower()
clean_titles_temp
# Out:
# 0         why
# 1      absurd
# 2         bro
# 3         how
# 4      waffen
#         ...
# 206       the
# 207      what
# 208      what
# 209       how
# 210      nasa
# Name: title, Length: 211, dtype: object

# %%
initial_words = clean_titles_temp.copy()
counts = initial_words.value_counts()
total = int(counts.sum())
top = counts.head()
print([{"word": w, "rate": float(c) / total}
       for w, c in top.items()])
# Out:
# [{'word': 'the', 'rate': 0.2132701421800948}, {'word': 'lego', 'rate': 0.061611374407582936}, {'word': 'what', 'rate': 0.05687203791469194}, {'word': 'why', 'rate': 0.037914691943127965}, {'word': 'life', 'rate': 0.03317535545023697}]

# %%
for channel_id, group in df.groupby("channel_id"):
    group["colon_rate"] = group["title"].astype(str).str.contains(r":").mean()

# %%
high_group
# Out:
#                    channel_id     video_id  \
# 127  UC_WXkNIJ2ncLIsAk_ltbvjA  7kQuVgRR-Qk
# 128  UC_WXkNIJ2ncLIsAk_ltbvjA  XDfDYCi4xBQ
# 142  UC_WXkNIJ2ncLIsAk_ltbvjA  gWUgLcA-8ps
# 143  UC_WXkNIJ2ncLIsAk_ltbvjA  Sxo2j9EugnU
# 145  UC_WXkNIJ2ncLIsAk_ltbvjA  wMm11lzsXM0
# 146  UC_WXkNIJ2ncLIsAk_ltbvjA  0-MQEvomCYU
# 148  UC_WXkNIJ2ncLIsAk_ltbvjA  fAnRIzHpxuE
# 149  UC_WXkNIJ2ncLIsAk_ltbvjA  mBIXXFPgTKI
# 150  UC_WXkNIJ2ncLIsAk_ltbvjA  DW8e0cKUr5U
# 151  UC_WXkNIJ2ncLIsAk_ltbvjA  Xe21Yh-Gi9Y
# 153  UC_WXkNIJ2ncLIsAk_ltbvjA  QUgY6kxrRDQ
# 154  UC_WXkNIJ2ncLIsAk_ltbvjA  9Z25P_XT8BI
#
#                                     title  \
# 127                When LEGO Gets Lazy...
# 128  MANY LEGO SETS THAT BREAK THE RULES!
# 142              200 IQ LEGO MINIFIGURES!
# 143    75 LEGO SETS THAT BREAK THE RULES!
# 145     LEGO Wants These Bricks Destroyed
# 146   LEGO Sets With Too Many Minifigures
# 148            300 IQ LEGO Play Features!
# 149                   EXTREME LEGO FAKES!
# 150                     800 IQ LEGO SETS!
# 151                   THE WORST LEGO SETS
# 153      Do You Remember These LEGO Sets?
# 154        LEGO Sets You Can't Take Apart
#
#                                                summary  views_in_period  \
# 127  This video reviews various LEGO sets, contrast...             3745
# 128  The video highlights a variety of mistakes and...             3370
# 142  This video explores the most creative and uniq...            18562
# 143  The video showcases a wide variety of accident...            15446
# 145  The video explores the fascinating and scandal...             7761
# 146  The video counts down the LEGO sets with the h...            67124
# 148  This video explores the most creative and clev...             3601
# 149  This video humorously explores the world of fa...             3504
# 150  The video explores the most ingenious and unco...             9707
# 151  The video reviews some of LEGO's worst sets ev...            42705
# 153  This video reviews several discontinued LEGO t...            13044
# 154  This video explores various LEGO sets and buil...            42402
#
#                                tokens
# 127                [lego, gets, lazy]
# 128        [lego, sets, break, rules]
# 142           [iq, lego, minifigures]
# 143        [lego, sets, break, rules]
# 145  [lego, wants, bricks, destroyed]
# 146         [lego, sets, minifigures]
# 148        [iq, lego, play, features]
# 149            [extreme, lego, fakes]
# 150                  [iq, lego, sets]
# 151               [worst, lego, sets]
# 153            [remember, lego, sets]
# 154               [lego, sets, apart]

# %%
low_group
# Out:
#                    channel_id     video_id  \
# 107  UC_WXkNIJ2ncLIsAk_ltbvjA  h989zfYFk2o
# 108  UC_WXkNIJ2ncLIsAk_ltbvjA  omPcR-Rum9U
# 109  UC_WXkNIJ2ncLIsAk_ltbvjA  2Y1ZHV3Nfig
# 110  UC_WXkNIJ2ncLIsAk_ltbvjA  l8ByqywIy3s
# 111  UC_WXkNIJ2ncLIsAk_ltbvjA  YCDqMf9cMnQ
# 112  UC_WXkNIJ2ncLIsAk_ltbvjA  LVfbHzKyvdE
# 113  UC_WXkNIJ2ncLIsAk_ltbvjA  4cjdNZxlOrE
# 114  UC_WXkNIJ2ncLIsAk_ltbvjA  Q23s9_oKbaU
# 115  UC_WXkNIJ2ncLIsAk_ltbvjA  mesRxwW_FfA
# 116  UC_WXkNIJ2ncLIsAk_ltbvjA  0Oirz0WCXJs
# 117  UC_WXkNIJ2ncLIsAk_ltbvjA  S49YQq8vtDY
# 118  UC_WXkNIJ2ncLIsAk_ltbvjA  pBLL9dy10Cs
# 119  UC_WXkNIJ2ncLIsAk_ltbvjA  sJCxP95iHgU
# 120  UC_WXkNIJ2ncLIsAk_ltbvjA  MRPS6Ypy30k
# 121  UC_WXkNIJ2ncLIsAk_ltbvjA  -JnviYGG0-0
# 122  UC_WXkNIJ2ncLIsAk_ltbvjA  slYdZawNRW4
# 123  UC_WXkNIJ2ncLIsAk_ltbvjA  8sNMonInDao
# 124  UC_WXkNIJ2ncLIsAk_ltbvjA  chwxNvc7jVk
# 125  UC_WXkNIJ2ncLIsAk_ltbvjA  S5y29ptlGtU
# 126  UC_WXkNIJ2ncLIsAk_ltbvjA  CRYjgo3O4Bk
# 129  UC_WXkNIJ2ncLIsAk_ltbvjA  PG_4Y2IXqlI
# 130  UC_WXkNIJ2ncLIsAk_ltbvjA  q6N2iBQHFT0
# 131  UC_WXkNIJ2ncLIsAk_ltbvjA  C_VWRaBg3dk
# 132  UC_WXkNIJ2ncLIsAk_ltbvjA  iZIKIwTZZK4
# 133  UC_WXkNIJ2ncLIsAk_ltbvjA  WvUWBa5jDlU
# 134  UC_WXkNIJ2ncLIsAk_ltbvjA  88wmTsMfZSk
# 135  UC_WXkNIJ2ncLIsAk_ltbvjA  Yh4B0QCuSBs
# 136  UC_WXkNIJ2ncLIsAk_ltbvjA  A5rxddBGzLE
# 137  UC_WXkNIJ2ncLIsAk_ltbvjA  A3PhuPZpR_g
# 138  UC_WXkNIJ2ncLIsAk_ltbvjA  qutXIIStW-w
# 139  UC_WXkNIJ2ncLIsAk_ltbvjA  yM4xPV-BoB8
# 140  UC_WXkNIJ2ncLIsAk_ltbvjA  jQ1v4AxaiIU
# 141  UC_WXkNIJ2ncLIsAk_ltbvjA  lnAcf3idJPI
# 144  UC_WXkNIJ2ncLIsAk_ltbvjA  vz_iQIp7Sg4
# 147  UC_WXkNIJ2ncLIsAk_ltbvjA  -fqIKZXwX8w
# 152  UC_WXkNIJ2ncLIsAk_ltbvjA  KoAPxfmjxeA
#
#                                         title  \
# 107                         400 IQ LEGO SETS!
# 108                  LEGO Has Gone Too Far...
# 109                 Misleading LEGO Bricks...
# 110        Weird vs Epic LEGO Set Stickers...
# 111   LOTS OF LEGO SETS THAT BREAK THE RULES!
# 112                         0 IQ LEGO SETS...
# 113            LEGO will NEVER be the same...
# 114          The Curse of Brittle LEGO Bricks
# 115    LEGO MINIFIGURES THAT BREAK THE RULES!
# 116         1000 IQ LEGO BUILDING TECHNIQUES!
# 117           Top 20 LEGO Sets For Christmas!
# 118                  LEGO’s Weird Obsessions…
# 119                         500 IQ LEGO SETS!
# 120                Craziest LEGO Hot Takes...
# 121                  $1 vs $100,000 LEGO Set!
# 122                      Awkward LEGO Sets...
# 123                      -200 IQ LEGO SETS...
# 124                LEGO Changed Everything...
# 125       The Worst LEGO Instruction Steps...
# 126                     LEGO Sets But Tiny...
# 129               The Hottest LEGO Hot Takes…
# 130                         600 IQ LEGO SETS!
# 131  These LEGO Minifigures Are Not Normal...
# 132         Crazy LEGO Conspiracy Theories...
# 133                200 IQ LEGO Play Features!
# 134            LEGO is hiding this in sets...
# 135                      LEGO But It Talks...
# 136                         700 IQ LEGO SETS!
# 137                  LEGO Has An Obsession...
# 138                  Insane LEGO Hot Takes...
# 139          THESE LEGO SETS BREAK THE RULES!
# 140         LEGO Capes Are 100x Better Now...
# 141                Weird LEGO Cars Be Like...
# 144         2000 IQ LEGO BUILDING TECHNIQUES!
# 147                LEGO's WORST Obsessions...
# 152                  LEGO is all connected...
#
#                                                summary  views_in_period  \
# 107  The video showcases a variety of Lego sets and...              193
# 108  The video counts down the ten Lego sets with t...               89
# 109  The video explains that while LEGO produces br...              164
# 110  The video explores the history, controversy, c...              158
# 111  The video highlights various rare and amusing ...             1446
# 112  This video explores some of LEGO’s most unusua...             1012
# 113  This video explores the evolution of LEGO mini...             2002
# 114  The video explores three major Lego conspiracy...              538
# 115  The video highlights various amusing and unusu...             2055
# 116  The video showcases a variety of ingenious and...             1802
# 117  The video presents a guide to the top 20 LEGO ...               21
# 118  The video explores LEGO's quirky obsessions wi...             1250
# 119  The video highlights clever and creative ways ...             1523
# 120  The video explores a range of controversial an...              966
# 121  This video explores the vast range of LEGO set...              251
# 122  The video humorously explores Lego’s long-runn...             1445
# 123  The video explores unusual, confusing, or seem...             2187
# 124  The video explores why LEGO avoids including r...             2375
# 125  This video reviews the most tedious and repeti...             3279
# 126  The video explores the history and creativity ...              494
# 129  The video explores a series of provocative and...              772
# 130  The video showcases creative and unexpected us...             1214
# 131  The video explores various rare and funny LEGO...              728
# 132  The video explores various Lego-related rumors...              379
# 133  The video highlights some of the weirdest, wac...             3359
# 134  This video explores clever and obscure Easter ...             2010
# 135  The video reviews the new $100 LEGO Harry Pott...              279
# 136  This video highlights clever and creative desi...             1903
# 137  The video explores LEGO’s quirky obsessions wi...             1249
# 138  The video explores a variety of viewer-submitt...              395
# 139  The video explores 15 LEGO sets with notable i...             1026
# 140  This video explores the history, evolution, an...             2255
# 141  This video explores the history and evolution ...              148
# 144  The video highlights some of the most creative...             2753
# 147  The video explores LEGO's recurring obsessions...              876
# 152  The video explores ten of the most clever hidd...             2490
#
#                                      tokens
# 107                        [iq, lego, sets]
# 108                       [lego, gone, far]
# 109              [misleading, lego, bricks]
# 110  [weird, vs, epic, lego, set, stickers]
# 111        [lots, lego, sets, break, rules]
# 112                        [iq, lego, sets]
# 113                                  [lego]
# 114          [curse, brittle, lego, bricks]
# 115       [lego, minifigures, break, rules]
# 116        [iq, lego, building, techniques]
# 117                 [lego, sets, christmas]
# 118               [lego, weird, obsessions]
# 119                        [iq, lego, sets]
# 120            [craziest, lego, hot, takes]
# 121                         [vs, lego, set]
# 122                   [awkward, lego, sets]
# 123                        [iq, lego, sets]
# 124                         [lego, changed]
# 125       [worst, lego, instruction, steps]
# 126                      [lego, sets, tiny]
# 129             [hottest, lego, hot, takes]
# 130                        [iq, lego, sets]
# 131             [lego, minifigures, normal]
# 132     [crazy, lego, conspiracy, theories]
# 133              [iq, lego, play, features]
# 134                    [lego, hiding, sets]
# 135                           [lego, talks]
# 136                        [iq, lego, sets]
# 137                       [lego, obsession]
# 138              [insane, lego, hot, takes]
# 139              [lego, sets, break, rules]
# 140             [lego, capes, 100x, better]
# 141               [weird, lego, cars, like]
# 144        [iq, lego, building, techniques]
# 147               [lego, worst, obsessions]
# 152                       [lego, connected]
